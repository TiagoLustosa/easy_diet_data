# %%
import pandas as pd

csv_ideal = pd.read_csv('C:/projects/easy_diet_data/data_files/user_data_mock_CSV11.csv')

csv_calculado = pd.read_csv('C:/projects/easy_diet_data/data_files/user_data_result11.csv')

df_concat = pd.concat([csv_ideal, csv_calculado], axis=1)



csv_ideal.head()[['totalProteinIdealInAllMeals', 'proteinSourceFirstMealFirstFoodProteinCoeficient']]
csv_calculado.head(3)[[
    'totalProteinCalculated', 'totalCaloriesCalculated',
    'firstMealProteinFoodTotalGrams','firstMealLipidFoodTotalGrams', 'firstMealCarboFoodTotalGrams', 
    'secondMealProteinFoodTotalGrams','secondMealLipidFoodTotalGrams', 'secondMealCarboFoodTotalGrams', 
    'thirdMealProteinFoodTotalGrams','thirdMealLipidFoodTotalGrams', 'thirdMealCarboFoodTotalGrams', 
    'fourthMealProteinFoodTotalGrams','fourthMealLipidFoodTotalGrams', 'fourthMealCarboFoodTotalGrams', ]]
# Out:
#    totalProteinCalculated  totalCaloriesCalculated
# 0              275.188079              3955.629187  \
# 1              243.201768              3134.261270
# 2              148.199200              2055.544134
#
#    firstMealProteinFoodTotalGrams  firstMealLipidFoodTotalGrams
# 0                             200                             4  \
# 1                             114                            32
# 2                              74                            13
#
#    firstMealCarboFoodTotalGrams  secondMealProteinFoodTotalGrams
# 0                           432                              228  \
# 1                           239                              272
# 2                            37                              115
#
#    secondMealLipidFoodTotalGrams  secondMealCarboFoodTotalGrams
# 0                             18                            413  \
# 1                              9                            226
# ...

# %%
df_concat.head(10)[['firstMealProteinFoodTotalGrams',
                       'firstMealLipidFoodTotalGrams', 
                       'firstMealCarboFoodTotalGrams', 
                       'secondMealProteinFoodTotalGrams', 
                       'secondMealLipidFoodTotalGrams',
                       'secondMealCarboFoodTotalGrams', 
                       'thirdMealProteinFoodTotalGrams', 
                       'thirdMealLipidFoodTotalGrams',
                       'thirdMealCarboFoodTotalGrams', 
                       'fourthMealProteinFoodTotalGrams', 
                       'fourthMealLipidFoodTotalGrams',
                       'fourthMealCarboFoodTotalGrams',
                       'totalProteinIdealInAllMeals',
                       'totalProteinCalculated',
                       'totalCaloriesIdealValue',
                       'totalCaloriesCalculated',
                       
                       ]]
# Out:
#    totalProteinIdealInAllMeals
# 0                        273.0  \
# 1                        241.3
# 2                        147.2
# 3                        155.2
# 4                        118.0
# 5                        178.2
# 6                        165.3
# 7                        100.7
# 8                        171.6
# 9                        189.0
#
#    proteinSourceFirstMealFirstFoodProteinCoeficient
# 0                                         26.686667  \
# 1                                         35.900000
# 2                                         35.900000
# 3                                         26.686667
# 4                                         35.900000
# 5                                         35.900000
# 6                                         26.686667
# 7                                         29.175000
# 8                                         29.175000
# 9                                         32.383333
#
# ...

# %%
import pandas as pd

df = pd.read_csv('full_result_predictTESTE.csv')
#df.columns.tolist()
df.head(3)[['totalProteinIdealInAllMeals',
 'totalLipidIdealInAllMeals',
 'totalCaloriesIdealValue',
 'totalProteinAllMeals',
 'totalLipidAllMeals',
 'totalCaloriesAllMeals','firstMealProteinFoodTotalGrams','firstMealLipidFoodTotalGrams', 'firstMealCarboFoodTotalGrams', 
    'secondMealProteinFoodTotalGrams','secondMealLipidFoodTotalGrams', 'secondMealCarboFoodTotalGrams', 
    'thirdMealProteinFoodTotalGrams','thirdMealLipidFoodTotalGrams', 'thirdMealCarboFoodTotalGrams', 
    'fourthMealProteinFoodTotalGrams','fourthMealLipidFoodTotalGrams', 'fourthMealCarboFoodTotalGrams']]
# Out:
#    totalProteinIdealInAllMeals  totalLipidIdealInAllMeals
# 0                        273.0                        130  \
# 1                        241.3                        127
# 2                        147.2                         92
#
#    totalCaloriesIdealValue  totalProteinAllMeals  totalLipidAllMeals
# 0              3955.399300             108.08620           51.787582  \
# 1              3133.692875             291.04117          138.246930
# 2              2055.256800             111.48384           61.545555
#
#    totalCaloriesAllMeals  firstMealProteinFoodTotalGrams
# 0              1787.1195                       63.821507  \
# 1              3368.6165                      142.861770
# 2              2149.1948                       53.574535
#
#    firstMealLipidFoodTotalGrams  firstMealCarboFoodTotalGrams
# 0                      4.047724                     146.55629  \
# 1                     36.822754                     263.31445
# ...

# %%
# negative_values = df[df['firstMealCarboFoodTotalGrams'] < 0]
# print(len(negative_values)) # retorna o numero de linhas com valores negativos -> 88rows
#
# negatives = df.lt(0).any() #retorna em quais colunas existem valores negativos

negative_values_first_carbo =  df[df['firstMealCarboFoodTotalGrams'] < 0]
negative_values_first_lipid =  df[df['firstMealLipidFoodTotalGrams'] < 0]
negative_values_second_carbo = df[df['secondMealCarboFoodTotalGrams'] < 0]
negative_values_second_lipid = df[df['secondMealLipidFoodTotalGrams'] < 0]
negative_values_third_carbo =  df[df['thirdMealCarboFoodTotalGrams'] < 0]
negative_values_third_lipid =  df[df['thirdMealLipidFoodTotalGrams'] < 0]
negative_values_fourth_carbo = df[df['fourthMealCarboFoodTotalGrams'] < 0]
negative_values_fourth_lipid = df[df['fourthMealLipidFoodTotalGrams'] < 0]

first_carbo_negative = len(negative_values_first_carbo)
first_lipid_negative = len(negative_values_first_lipid)
second_carbo_negative = len(negative_values_second_carbo)
second_lipid_negative = len(negative_values_second_lipid)
third_carbo_negative = len(negative_values_third_carbo)
third_lipid_negative = len(negative_values_third_lipid)
fourth_carbo_negative = len(negative_values_fourth_carbo)
fourth_lipid_negative = len(negative_values_fourth_lipid)
negatives = df.lt(0).any() 
print(negatives)
print('neg_first_carbo',  first_carbo_negative)
print('neg_first_lipid',  first_lipid_negative)
print('neg_second_carbo', second_carbo_negative)
print('neg_second_lipid', second_lipid_negative)
print('neg_third_carbo',  third_carbo_negative)
print('neg_third_lipid',  third_lipid_negative)
print('neg_fourth_carbo', fourth_carbo_negative)
print('neg_fourth_lipid', fourth_lipid_negative)
# Out:
# totalProteinIdealInAllMeals        False
# totalProteinAllMeals               False
# totalLipidIdealInAllMeals          False
# totalLipidAllMeals                 False
# totalCaloriesIdealValue            False
# totalCaloriesAllMeals              False
# firstMealProteinFoodTotalGrams     False
# firstMealLipidFoodTotalGrams       False
# firstMealCarboFoodTotalGrams        True
# secondMealProteinFoodTotalGrams    False
# secondMealLipidFoodTotalGrams      False
# secondMealCarboFoodTotalGrams       True
# thirdMealProteinFoodTotalGrams     False
# thirdMealLipidFoodTotalGrams       False
# thirdMealCarboFoodTotalGrams        True
# fourthMealProteinFoodTotalGrams    False
# fourthMealLipidFoodTotalGrams       True
# fourthMealCarboFoodTotalGrams       True
# dtype: bool
# neg_first_carbo 11
# neg_first_lipid 0
# neg_second_carbo 6
# neg_second_lipid 0
# neg_third_carbo 7
# neg_third_lipid 0
# neg_fourth_carbo 9
# neg_fourth_lipid 1

# %%
negative_row = df[df<0].any(axis=1)
row_number = negative_row.where(negative_row).dropna().index
print(row_number)
# Out:
# Index([ 54,  63,  98, 113, 148, 206, 367, 400, 405, 440, 444, 452, 492, 524,
#        525, 526, 565, 568, 580, 587, 762, 785, 806, 812, 815, 817, 820, 824,
#        859],
#       dtype='int64')

# %%
#remove todas as linhas com valores negativos
df = df[(df >= 0).all(1)]
print(len(df))
df.head(10)
# Out:
# 871
#    totalProteinIdealInAllMeals  totalProteinAllMeals
# 0                        273.0             107.71181  \
# 1                        241.3             289.29718
# 2                        147.2             111.65466
# 3                        155.2             120.00728
# 4                        118.0             141.06328
# 5                        178.2              86.53677
# 6                        165.3             101.34385
# 7                        100.7             255.84242
# 8                        171.6              72.87734
# 9                        189.0             276.09260
#
#    totalLipidIdealInAllMeals  totalLipidAllMeals  totalCaloriesIdealValue
# 0                        130           52.726894              3977.399300  \
# 1                        127          131.093670              3133.692875
# 2                         92           61.910970              2055.256800
# 3                         97           58.768147              2318.416375
# ...

# %%
#check if protein and calories it's ok
isProteinBigger = df['totalProteinAllMeals'] >= df['totalProteinIdealInAllMeals'] + (df['totalProteinIdealInAllMeals']  * 0.05) 
isProteinLower = df['totalProteinAllMeals'] < df['totalProteinIdealInAllMeals']

isLipidBigger = df['totalCaloriesAllMeals'] >= df['totalCaloriesIdealValue'] + (df['totalCaloriesIdealValue']  * 0.05) 
isLipidLower = df['totalCaloriesAllMeals'] < (df['totalCaloriesIdealValue'] - (df['totalCaloriesIdealValue'] * 0.03))

isCaloriesBigger = df['totalCaloriesAllMeals'] >= df['totalCaloriesIdealValue'] + (df['totalCaloriesIdealValue']  * 0.05) 
isCaloriesLower = df['totalCaloriesAllMeals'] < (df['totalCaloriesIdealValue'] - (df['totalCaloriesIdealValue'] * 0.03))


proteinIsOkAllMeals = ((isProteinBigger == False) & (isProteinLower == False))               
lipidIsOkAllMeals = ((isLipidBigger == False) & (isLipidLower == False))       
caloriesIsOkAllMeals = ((isCaloriesBigger == False) & (isCaloriesLower == False))       
print((proteinIsOkAllMeals))
print((lipidIsOkAllMeals))
print((caloriesIsOkAllMeals))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 895    False
# 896    False
# 897    False
# 898    False
# 899    False
# Length: 871, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 895    False
# 896    False
# 897    False
# 898    False
# 899    False
# Length: 871, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 895    False
# 896    False
# 897    False
# 898    False
# 899    False
# Length: 871, dtype: bool
