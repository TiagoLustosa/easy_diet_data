# %%
import pandas as pd

csv_ideal = pd.read_csv('C:/projects/easy_diet_data/data_files/user_data_mock_CSV.csv')

csv_calculado = pd.read_csv('C:/projects/easy_diet_data/data_files/user_data_result.csv')

# df = pd.concat([csv_ideal, csv_calculado], axis=1)
pd.options.display.width = 20

style = csv_calculado.style
style.set_properties(subset=[''])
csv_calculado.head()
# Out:
#    totalProteinIdealValue
# 0                121.9     \
# 1                105.0
# 2                220.8
# 3                147.0
# 4                 85.0
#
#    totalCaloriesIdealValue
# 0          2882.259500      \
# 1          2049.279375
# 2          3751.698500
# 3          1826.654400
# 4          2095.720000
#
#    firstMealProteinFoodTotalGrams
# 0                   71             \
# 1                  108
# 2                   96
# 3                   85
# 4                   77
#
#    firstMealProteinFoodTotalKcal
# 0           115.641082            \
# 1           251.514068
# 2           223.568061
# 3           197.950887
# 4           168.829635
#
#    firstMealLipidFoodTotalGrams
# 0                   30           \
# 1                   10
# 2                   15
# 3                   15
# 4                   11
#
#    firstMealLipidFoodTotalKcal
# 0           171.050288          \
# 1            88.400000
# 2            90.867164
# 3            90.867164
# 4            97.240000
#
#    firstMealCarboFoodTotalGrams
# 0                  414           \
# 1                  209
# 2                  242
# 3                  410
# 4                  454
#
#    firstMealCarboFoodTotalKcal
# 0           213.576293          \
# 1           160.427586
# 2           185.758257
# 3           211.512754
# 4           234.211684
#
#    secondMealProteinFoodTotalGrams
# 0                  113              \
# 1                  147
# 2                  116
# 3                  145
# 4                  153
#
#    secondMealProteinFoodTotalKcal
# 0           247.762971             \
# 1           312.257988
# 2           254.340749
# 3           308.009580
# 4           356.311597
#
#    ...
# 0  ...  \
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    thirdMealCarboFoodTotalGrams
# 0                  170           \
# 1                   67
# 2                  171
# 3                  414
# 4                  188
#
#    thirdMealCarboFoodTotalKcal
# 0           210.009317          \
# 1           248.652151
# 2           211.244666
# 3           213.576293
# 4           232.245598
#
#    fourthMealProteinFoodTotalGrams
# 0                  -63              \
# 1                  -49
# 2                  308
# 3                  102
# 4                 -128
#
#    fourthMealProteinFoodTotalKcal
# 0          -102.611101             \
# 1          -107.150799
# 2           673.519308
# 3           223.048602
# 4          -298.090748
#
#    fourthMealLipidFoodTotalGrams
# 0                   15            \
# 1                  -33
# 2                   15
# 3                   -2
# 4                    4
#
#    fourthMealLipidFoodTotalKcal
# 0            85.525144           \
# 1          -188.155317
# 2            90.867164
# 3           -12.115622
# 4            24.231244
#
#    fourthMealCarboFoodTotalGrams
# 0                  930            \
# 1                  462
# 2                  986
# 3                    1
# 4                  805
#
#    fourthMealCarboFoodTotalKcal
# 0          1148.874500           \
# 1           592.554204
# 2          1236.032345
# 3             3.711226
# 4           617.914865
#
#    totalProteinCalculated
# 0           122.040302     \
# 1           104.684545
# 2           223.701658
# 3           147.786725
# 4            83.860089
#
#    totalCaloriesCalculated
# 0          2883.406007
# 1          2049.659320
# 2          3752.183054
# 3          1966.193862
# 4          2095.951252
#
# [5 rows x 28 columns]
